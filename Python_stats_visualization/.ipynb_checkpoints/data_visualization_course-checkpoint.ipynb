# %%
import glob
import pandas as pd
import glob
import seaborn as sns
import pingouin as pg
import matplotlib.pyplot as plt

# %%
'''Example to load all the individual result files'''

files_1h = glob.glob("results_1h/*Results*.csv")
file_count_1h = len(files_1h)

print(f"In total we have {file_count_1h} files")
# Out:
# In total we have 4 files

# %%
# create empty list
dataframes_list_1h = []
  
# append datasets to the list 
for i in range(file_count_1h):
    temp_df = pd.read_csv(files_1h[i])
    dataframes_list_1h.append(temp_df)
      
# display datsets
for dataset_1h in dataframes_list_1h:
    display(dataset_1h)
# Out:
#            Area     Mean  StdDev  Min  Max      X      Y     XM     YM  Major  \
# 0      1  0.044   64.477  30.830    0  188  1.381  0.379  1.383  0.379  0.250
# 1      2  0.035   67.658  27.561    0  191  8.230  0.464  8.230  0.465  0.223
# 2      3  0.050   76.330  36.590    4  238  2.506  0.580  2.511  0.584  0.259
# 3      4  0.046   63.455  31.105    0  196  0.850  0.634  0.847  0.633  0.267
# 4      5  0.047   63.253  29.671    0  209  5.149  0.667  5.150  0.663  0.262
# ..   ...    ...      ...     ...  ...  ...    ...    ...    ...    ...    ...
# 140  141  0.048   67.074  34.309    0  219  3.918  8.165  3.916  8.164  0.274
# 141  142  0.048   65.526  33.034    0  203  3.689  8.363  3.687  8.362  0.290
# 142  143  0.055   63.331  31.010    0  188  2.380  8.357  2.389  8.356  0.284
# 143  144  0.043   76.791  33.273    2  216  4.595  8.369  4.594  8.367  0.254
# 144  145  0.030  111.254  43.438   19  254  0.809  8.407  0.810  8.406  0.239
#
#      Minor    Angle  %Area
# 0    0.225  108.922      0
# 1    0.201   83.425      0
# 2    0.245  156.860      0
# 3    0.221  146.134      0
# 4    0.227  124.637      0
# ..     ...      ...    ...
# 140  0.223  146.207      0
# 141  0.212  127.197      0
# 142  0.248  168.412      0
# 143  0.218   18.184      0
# 144  0.158  110.104      0
#
# [145 rows x 14 columns]
#            Area     Mean  StdDev  Min  Max      X      Y     XM     YM  Major  \
# 0      1  0.016  131.189  42.839   38  254  5.182  0.685  5.179  0.684  0.180
# 1      2  0.024  133.596  43.433   34  254  7.351  0.726  7.349  0.729  0.229
# 2      3  0.012   93.554  29.881   34  195  1.952  0.801  1.950  0.799  0.158
# 3      4  0.002   87.320  24.371   46  156  2.171  0.778  2.170  0.778  0.068
# 4      5  0.006  111.526  35.968   39  227  5.141  0.808  5.139  0.808  0.095
# ..   ...    ...      ...     ...  ...  ...    ...    ...    ...    ...    ...
# 134  135  0.026  148.813  50.393   30  254  3.132  7.703  3.131  7.699  0.198
# 135  136  0.028  107.803  33.492   41  254  4.763  7.796  4.764  7.794  0.268
# 136  137  0.023  141.081  50.068   31  254  5.611  7.819  5.608  7.817  0.237
# 137  138  0.028  102.974  29.300   38  241  0.858  8.410  0.861  8.409  0.222
# 138  139  0.015  110.651  35.715   41  242  3.506  8.457  3.508  8.459  0.189
#
#      Minor    Angle  %Area
# 0    0.116  121.679      0
# 1    0.135   43.132      0
# 2    0.095  101.816      0
# 3    0.046  103.761      0
# 4    0.082   79.229      0
# ..     ...      ...    ...
# 134  0.165   22.383      0
# 135  0.135   66.068      0
# 136  0.125  173.001      0
# 137  0.159  117.662      0
# 138  0.104   14.192      0
#
# [139 rows x 14 columns]
#           Area     Mean  StdDev  Min  Max      X      Y     XM     YM  Major  \
# 0    1  0
# ..  ..    ...      ...     ...  ...  ...    ...    ...    ...    ...    ...
# 61  62  0.028  202.755  51.557   69  254  3.161  7.830  3.162  7.832  0.276
# 62  63  0.027  203.290  51.300   67  254  4.741  7.912  4.745  7.914  0.228
# 63  64  0.035  204.951  47.413   74  254  1.149  8.134  1.152  8.134  0.217
# 64  65  0.029  199.853  50.752   63  254  5.055  8.199  5.057  8.202  0.248
# 65  66  0.027  204.983  50.922   54  254  4.805  8.199  4.807  8.199  0.208
#
#     Minor    Angle  %Area Group
# 0   0.225  108.922      0    1h
# 1   0.201   83.425      0    1h
# 2   0.245  156.860      0    1h
# 3   0.221  146.134      0    1h
# 4   0.227  124.637      0    1h
# ..    ...      ...    ...   ...
# 61  0.130  153.232      0    1h
# 62  0.150  147.223      0    1h
# 63  0.203  137.148      0    1h
# 64  0.149   40.176      0    1h
# 65  0.164   48.186      0    1h
#
# [429 rows x 15 columns]

# %%
'''Example to load all the individual result files'''

files_4h = glob.glob("results_4h/*Results*.csv")
file_count_4h = len(files_4h)

print(f"In total we have {file_count_4h} files")
# Out:
# In total we have 4 files

# %%
# create empty list
dataframes_list_4h = []
  
# append datasets to the list 
for i in range(file_count_4h):
    temp_df = pd.read_csv(files_4h[i])
    dataframes_list_4h.append(temp_df)
      
# display datsets
for dataset_4h in dataframes_list_4h:
    display(dataset_4h)
# Out:
#            Area     Mean  StdDev  Min  Max      X      Y     XM     YM  Major  \
# 0      1  0.028  172.928  47.358   59  254  6.579  0.554  6.578  0.551  0.253
# 1      2  0.016  164.748  45.637   65  254  3.742  0.531  3.746  0.528  0.157
# 2      3  0.021  215.559  50.272   52  254  6.308  0.644  6.307  0.643  0.192
# 3      4  0.028  171.028  42.679   61  254  7.105  0.804  7.104  0.802  0.231
# 4      5  0.038  148.850  40.856   63  254  4.859  1.009  4.861  1.008  0.254
# ..   ...    ...      ...     ...  ...  ...    ...    ...    ...    ...    ...
# 100  101  0.028  197.701  46.884   65  254  1.496  7.873  1.496  7.872  0.224
# 101  102  0.029  198.277  46.855   57  254  1.913  8.131  1.915  8.130  0.235
# 102  103  0.033  166.500  45.150   65  254  1.559  8.149  1.557  8.148  0.253
# 103  104  0.028  194.904  50.768   52  254  2.265  8.362  2.265  8.360  0.218
# 104  105  0.033  143.413  34.219   54  254  4.996  8.436  4.996  8.436  0.272
#
#      Minor    Angle  %Area
# 0    0.141  111.130      0
# 1    0.127   20.368      0
# 2    0.136  136.056      0
# 3    0.157  105.930      0
# 4    0.188   70.193      0
# ..     ...      ...    ...
# 100  0.158   40.877      0
# 101  0.157  116.391      0
# 102  0.167   53.225      0
# 103  0.165  167.360      0
# 104  0.153   10.765      0
#
# [105 rows x 14 columns]
#            Area     Mean  StdDev  Min  Max      X      Y     XM     YM  Major  \
# 0      1  0.041   99.907  43.789    3  254  6.689  0.708  6.685  0.708  0.240
# 1      2  0.036  122.468  42.563   34  254  0.701  0.705  0.698  0.708  0.219
# 2      3  0.035   96.316  38.839    4  246  3.477  0.836  3.482  0.838  0.236
# 3      4  0.036   93.174  34.315   10  239  3.870  0.836  3.870  0.838  0.226
# 4      5  0.043   76.244  36.104    0  251  4.364  0.851  4.363  0.853  0.257
# ..   ...    ...      ...     ...  ...  ...    ...    ...    ...    ...    ...
#
#
#     Minor    Angle  %Area
# 0   0.149  109.675      0
# 1   0.168  103.232      0
# 2   0.122   86.652      0
# 3   0.169  105.831      0
# 4   0.153  125.561      0
# ..    ...      ...    ...
# 94  0.146    4.983      0
# 95  0.183  171.581      0
# 96  0.150   41.806      0
# 97  0.153  105.942      0
# 98  0.137   16.753      0
#
# [99 rows x 14 columns]

# %%
df_4h = pd.concat(dataframes_list_4h, axis=0)
df_4h['Group'] = '4h'
df_4h
# Out:
#          Area     Mean  StdDev  Min  Max      X      Y     XM     YM  Major  \
# 0    1  0.028  172.928  47.358   59  254  6.579  0.554  6.578  0.551  0.253
# 1    2  0.016  164.748  45.637   65  254  3.742  0.531  3.746  0.528  0.157
# 2    3  0.021  215.559  50.272   52  254  6.308  0.644  6.307  0.643  0.192
# 3    4  0.028  171.028  42.679   61  254  7.105  0.804  7.104  0.802  0.231
# 4    5  0.038  148.850  40.856   63  254  4.859  1.009  4.861  1.008  0.254
# ..  ..    ...      ...     ...  ...  ...    ...    ...    ...    ...    ...
# 94  95  0.021  176.111  49.294   62  254  4.926  8.279  4.932  8.280  0.180
# 95  96  0.035  197.632  49.833   69  254  4.023  8.313  4.022  8.312  0.242
# 96  97  0.018  185.282  49.239   58  254  5.832  8.432  5.829  8.432  0.156
# 97  98  0.022  177.403  49.386   65  254  4.846  8.496  4.842  8.496  0.183
# 98  99  0.021  169.126  47.500   58  254  5.232  8.485  5.231  8.489  0.197
#
#     Minor    Angle  %Area Group
# 0   0.141  111.130      0    4h
# 1   0.127   20.368      0    4h
# 2   0.136  136.056      0    4h
# 3   0.157  105.930      0    4h
# 4   0.188   70.193      0    4h
# ..    ...      ...    ...   ...
# 94  0.146    4.983      0    4h
# 95  0.183  171.581      0    4h
# 96  0.150   41.806      0    4h
# 97  0.153  105.942      0    4h
# 98  0.137   16.753      0    4h
#
# [430 rows x 15 columns]

# %%
print(df_1h.describe())
print(df_4h.describe())
# Out:
#                          Area        Mean      StdDev         Min         Max  \
# count  429.000000  429.000000  429.000000  429.000000  429.000000  429.000000
# mean    59.874126    0.031108  122.900312   39.080408   31.365967  235.020979
# std     39.245489    0.015621   48.799200    9.770473   22.448151   29.929232
# min      1.000000    0.000544   58.297000   13.733000    0.000000  104.000000
# 25%     27.000000    0.022000   80.360000   32.254000    8.000000  223.000000
# 50%     54.000000    0.029000  107.057000   37.727000   33.000000  254.000000
# 75%     89.000000    0.043000  167.954000   47.505000   52.000000  254.000000
# max    145.000000    0.101000  223.672000   63.650000   78.000000  254.000000
#
#                 X           Y          XM          YM       Major       Minor  \
# count  429.000000  429.000000  429.000000  429.000000  429.000000  429.000000
# mean     3.975828    4.478527    3.975970    4.478664    0.222014    0.166110
# std      2.273651    2.206827    2.273672    2.206774    0.064576    0.056152
# min      0.167000    0.379000    0.163000    0.379000    0.026000    0.026000
# 25%      2.066000    2.556000    2.066000    2.553000    0.195000    0.134000
# 50%      3.825000    4.491000    3.824000    4.491000    0.230000    0.169000
# 75%      5.771000    6.323000    5.771000    6.321000    0.261000    0.210000
# 97  0.153  105.942      0    4h
# 98  0.137   16.753      0    4h
#
# [859 rows x 15 columns]

# %%
plt.figure(figsize=(8, 8))
sns.boxplot(data = df_together, x='Group', y='Area', palette="Set3")
sns.stripplot(data = df_together, x='Group', y='Area', color = "black")
plt.ylabel('Number of objects', fontsize = 20)
plt.xlabel('Experiment', fontsize = 20)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
sns.despine()
plt.tight_layout()
plt.savefig('Counts.png', dpi = 300)

# %%
'''Other way of representing the data'''

plt.figure(figsize=(10, 10))
sns.violinplot(data = df_together, x='Group', y='Area', palette="Set3")
sns.stripplot(data = df_together, x='Group', y='Area', color = "black")
sns.despine()
plt.tight_layout()
plt.savefig('Counts_violinplots.png', dpi = 300)

# %% [markdown]
# # Pingouin is an open-source statistical package written in Python 3
#
# https://pingouin-stats.org/#

# %%
pg.ttest(df_1h.Area, df_4h.Area)
# Out:
#                T         dof       tail         p-val        CI95%   cohen-d  \
# T-test  4.995508  669.592392  two-sided  7.496529e-07  [0.0, 0.01]  0.341099
#
#              BF10     power
# T-test  1.389e+04  0.998789

# %% [markdown]
# # Is the data normal?

# %%
print(pg.normality(df_1h.Area))
print(pg.normality(df_4h.Area))
# Out:
#              W      pval  normal
# Area  0.976816  0.000002   False
#             W          pval  normal
# Area  0.95573  4.555235e-10   False

# %% [markdown]
# ## The Kruskal-Wallis H-test
#
# The Kruskal-Wallis H-test tests the null hypothesis that the population median of all of the groups are equal. It is a non-parametric version of ANOVA. The test works on 2 or more independent samples, which may have different sizes. Due to the assumption that H has a chi square distribution, the number of samples in each group must not be too small. A typical rule is that each sample must have at least 5 measurements.

# %%
pg.kruskal(df_together, dv= 'Area', between= 'Group')
# Out:
#         Source  ddof1         H         p-unc
# Kruskal  Group      1  29.13141  6.763158e-08

# %% [markdown]
# ## The Mann–Whitney U test (also called Wilcoxon rank-sum test) is a non-parametric test of the null hypothesis

# %%
p1 = pg.mwu(df_1h.Area, df_4h.Area)
p1
# Out:
#         U-val       tail         p-val       RBC      CLES
# MWU  111849.0  two-sided  6.768344e-08 -0.212652  0.606326

# %%
p2 = pg.mwu(df_1h.Max, df_4h.Max)
p2
# Out:
#        U-val       tail         p-val     RBC    CLES
# MWU  60912.0  two-sided  1.434236e-28  0.3396  0.3302

# %%
p3 = pg.mwu(df_1h.Mean, df_4h.Mean)
p3
# Out:
#        U-val       tail         p-val       RBC      CLES
# MWU  44596.0  two-sided  3.208200e-39  0.516496  0.241752

# %% [markdown]
# # P-values correction for multiple comparisons.

# %%
'''Benjamini–Hochberg FDR correction of an array of p-values'''

pvals = [p1['p-val'].values[0], p2['p-val'].values[0], p3['p-val'].values[0]]
reject, pvals_corr = pg.multicomp(pvals, method='fdr_bh')
print(reject, pvals_corr)
# Out:
# [ True  True  True] [6.76834427e-08 2.15135456e-28 9.62459870e-39]

# %% [markdown]
# # There are many ways to vizualize the data

# %%
df_together.head()
# Out:
#        Area    Mean  StdDev  Min  Max      X      Y     XM     YM  Major  \
# 0  1  0.044  64.477  30.830    0  188  1.381  0.379  1.383  0.379  0.250
# 1  2  0.035  67.658  27.561    0  191  8.230  0.464  8.230  0.465  0.223
# 2  3  0.050  76.330  36.590    4  238  2.506  0.580  2.511  0.584  0.259
# 3  4  0.046  63.455  31.105    0  196  0.850  0.634  0.847  0.633  0.267
# 4  5  0.047  63.253  29.671    0  209  5.149  0.667  5.150  0.663  0.262
#
#    Minor    Angle  %Area Group
# 0  0.225  108.922      0    1h
# 1  0.201   83.425      0    1h
# 2  0.245  156.860      0    1h
# 3  0.221  146.134      0    1h
# 4  0.227  124.637      0    1h

# %%
sns.pairplot(df_together, height = 1.5, diag_kind="kde")
# Out:
# /Users/fernandesm/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns.kdeplot(data = df_1h['Mean'])
sns.kdeplot(data = df_4h['Mean'])
# Out:
# <AxesSubplot:xlabel='Mean', ylabel='Density'>

# %%
sns.kdeplot(data = df_1h['Mean'])
sns.rugplot(data = df_1h['Mean'], height= 0.1)
# Out:
# <AxesSubplot:xlabel='Mean', ylabel='Density'>

# %%
df_together
# Out:
#          Area     Mean  StdDev  Min  Max      X      Y     XM     YM  Major  \
# 0    1  0.044   64.477  30.830    0  188  1.381  0.379  1.383  0.379  0.250
# 1    2  0.035   67.658  27.561    0  191  8.230  0.464  8.230  0.465  0.223
# 2    3  0.050   76.330  36.590    4  238  2.506  0.580  2.511  0.584  0.259
# 3    4  0.046   63.455  31.105    0  196  0.850  0.634  0.847  0.633  0.267
# 4    5  0.047   63.253  29.671    0  209  5.149  0.667  5.150  0.663  0.262
# ..  ..    ...      ...     ...  ...  ...    ...    ...    ...    ...    ...
# 94  95  0.021  176.111  49.294   62  254  4.926  8.279  4.932  8.280  0.180
# 95  96  0.035  197.632  49.833   69  254  4.023  8.313  4.022  8.312  0.242
# 96  97  0.018  185.282  49.239   58  254  5.832  8.432  5.829  8.432  0.156
# 97  98  0.022  177.403  49.386   65  254  4.846  8.496  4.842  8.496  0.183
# 98  99  0.021  169.126  47.500   58  254  5.232  8.485  5.231  8.489  0.197
#
#     Minor    Angle  %Area Group
# 0   0.225  108.922      0    1h
# 1   0.201   83.425      0    1h
# 2   0.245  156.860      0    1h
# 3   0.221  146.134      0    1h
# 4   0.227  124.637      0    1h
# ..    ...      ...    ...   ...
# 94  0.146    4.983      0    4h
# 95  0.183  171.581      0    4h
# 96  0.150   41.806      0    4h
# 97  0.153  105.942      0    4h
# 98  0.137   16.753      0    4h
#
# [859 rows x 15 columns]

# %%
sns.barplot(data = df_together, x='Group', y='Mean', palette="Set3", ci="sd", capsize=.2)
# Out:
# <AxesSubplot:xlabel='Group', ylabel='Mean'>

# %%
sns.histplot(df_together.Area)
# Out:
# <AxesSubplot:xlabel='Area', ylabel='Count'>

# %%
df_together.plot(kind='hexbin', x='X', y='Area')
# Out:
# <AxesSubplot:xlabel='X', ylabel='Area'>
